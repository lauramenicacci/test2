# %% [markdown]
# <a href="https://colab.research.google.com/github/lauramenicacci/test2/blob/main/Copy_of_GitHubAccess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %% [markdown]
# ## Setting up the GitHub repository (only one student per group!)

# %% [markdown]
# To be able to work on the project collaboratively via GitHub (and not via GoogleColab itself), one student (!) has to create a repository on GitHub. From [this tutorial](https://medium.com/analytics-vidhya/how-to-use-google-colab-with-github-via-google-drive-68efb23a42d) (Step 5.A.3), we see how it's done:
#
#
#
# *   Visit GitHub official website and login with your account.
# *   Create a new repository in GitHub. Note: Do not forget to tick __Add a  README file__.
#
# ![Screenshot from 2022-01-25 17-08-06.png](data:image/png;base64,...)
#
# Change the repository name.

# %% [markdown]
# ---
#
# The same student has to create a personal access key. Again from [this tutorial](https://medium.com/analytics-vidhya/how-to-use-google-colab-with-github-via-google-drive-68efb23a42d) (Step 4):
#
#
# *   Visit the GitHub website and login to your account.
# *   Go to __Settings__, navigate to __Developer settings__ and then click on __Personal access tokens__.
# *   Click on __Generate new token__ button on top right corner of the page.
# *   Click the __repo__ checkbox under Select scopes section as shown,
# ![1_k74phx_Vg5CJaDcIBjbHlA.png](data:image/png;base64,...)
# *   Now, click on __Generate token__ button at the bottom of the page. Now, the page should look like,
# ![1_3PLAa2fn_E5V3wTKCmwDQg.png](data:image/png;base64,...)

# %% [markdown]
# Copy the Access token and include it down in the next code section.

# %% [markdown]
# ## Setup git in your Google Drive (every student in the group)

# %% [markdown]
# Note: If you haven't set up the GitHub repository (section above), ask your group member who completed this step, for the personal access token and include it down here.

# %%
git_token = "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"

# %% [markdown]
# First, we need to add GoogleDrive to this notebook.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Then, we need to define the folder where we want to save our project.

# %%
folder_name = "GRAD-C24_Machine_Learning"
# %mkdir -p /content/drive/MyDrive/{folder_name}
# %cd /content/drive/MyDrive/{folder_name}
# Out:
# /content/drive/MyDrive/GRAD-C24_Machine_Learning

# %% [markdown]
# We add access to this repository via these commands.

# %%
username = "mcsteinTest"
repository = "mlLabASessions1Test"

# %%
# !git clone https://github.com/{username}/{repository}.git
# %cd {repository}
# Out:
# Cloning into 'mlLabASessions1Test'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# /content/drive/MyDrive/GRAD-C24_Machine_Learning/mlLabASessions1Test

# %%
# !git config --global init.defaultBranch main
# !git init
# !git remote set-url origin https://{git_token}@github.com/{username}/{repository}.git
# !git remote -v
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/GRAD-C24_Machine_Learning/mlLabASessions1Test/.git/
# origin	https://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@github.com/mcsteinTest/mlLabASessions1Test.git (fetch)
# origin	https://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@github.com/mcsteinTest/mlLabASessions1Test.git (push)

# %%
# !git pull origin main
# Out:
# From https://github.com/mcsteinTest/mlLabASessions1Test
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %% [markdown]
# Let's define the username so GitHub knows who commited the changes (the e-mail address here corresponds to the email address you use on GitHub).

# %%
# !git config --global user.name "YourName"
# !git config --global user.email "YourEmail@Address"

# %% [markdown]
# # Commit changes and push

# %%
print("hello_world")
# Out:
# hello_world

# %% [markdown]
# Let's be safe, we are in the correct folder. What's the project folder structure again?

# %%
# %cd /content/drive/MyDrive/GRAD-C24_Machine_Learning/mlLabASessions1Test/
# Out:
# /content/drive/MyDrive/GRAD-C24_Machine_Learning/mlLabASessions1Test

# %% [markdown]
# Check the status of your current changes.

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# And see if there is anything new online.

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !touch "HelloWorld.txt"

# %%
# !git status

# %% [markdown]
# Add the desired files for commiting. `!git add .` will add all files which were changes whereas adding specific files will be done with `!git add <specific_file1> <specific_file2>`.

# %%
# !git add .

# %% [markdown]
# Let's commit our changes. Try to find an explanatory message for the changes you have made so far.

# %%
# !git commit -m "Include hello world message"

# %%
# !git status

# %% [markdown]
# Let's push our local changes to GitHub. The command should be `!git push -u <remote-name> <branch-name>`. Usually we want to push it to `origin` and we usually work on the `master`-branch.

# %%
# !git push -u origin main

# %% [markdown]
# Running `!git status` should return something like:
#
#
#
# ```
# ...
# Your branch is up to date with ...
#
# nothing to commit, working tree clean
# ```
